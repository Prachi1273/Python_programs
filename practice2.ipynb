# %%
from sympy import*

# %%
x=Point(0,0)
y=Point(2,2)
z=Point(-1,-1)
w=Point(3,4)

# %%
#distance betn (x,y)
x.distance(y)
# Out:
# 2*sqrt(2)

# %%
#distance betn (y,z)
y.distance(z)
# Out:
# 3*sqrt(2)

# %%
#distance betn (x,w)
x.distance(w)
# Out:
# 5

# %%
#scalling in x coordinate by factor 5
w.scale(5,0)
# Out:
# Point2D(15, 0)

# %%
#scalling in y coordinate by factor 2
y.scale(0,2)
# Out:
# Point2D(0, 4)

# %%
#scalling in x and y coordinate by factors 4,9
z.scale(4,9)
# Out:
# Point2D(-4, -9)

# %%
#scalling in x and y coordinate by factor 6,8 on point(3,7)
p=Point(3,7)

# %%
p.scale(6,8)
# Out:
# Point2D(18, 56)

# %%
from sympy import*
x,y=symbols('x,y')
p=Point(3,6)
p.reflect(Line(x+y))
# Out:
# Point2D(-6, -3)

# %%
from sympy import *

# %%
#(0,-2), x+y=5
x,y=symbols('x,y')
p=Point(0,-2)
p.reflect(Line(x+y-5))
# Out:
# Point2D(7, 5)

# %%
a=Point(5,3)
b=Point(1,4)
x,y=symbols('x,y')
s=Segment(a,b)
L=Line(y-x-1)
s.reflect(L)
# Out:
# Segment2D(Point2D(2, 6), Point2D(3, 2))

# %%
p=Point(3,-1)
p.scale(2,0)
# Out:
# Point2D(6, 0)

# %%
p.scale(0,1.5)
# Out:
# Point2D(0, -3/2)

# %%
x,y=symbols('x,y')
p.reflect(Line(x+y+0))#reflect line y=x
# Out:
# Point2D(1, -3)

# %%
A=Point(5,-2)
B=Point(4,3)
S=Segment(A,B)
S.scale(2,0)
# Out:
# Segment2D(Point2D(10, 0), Point2D(8, 0))

# %%
z=Point(4,-2)
z.reflect(Line(y-0))
# Out:
# Point2D(4, 2)

# %%
z.scale(3,0)
# Out:
# Point2D(12, 0)

# %%
z.scale(0,2.5)
# Out:
# Point2D(0, -5)

# %%
l=Line(4*x+3*y-5)
l1=Line(x+y)
l2=l.reflect(l1)
l2.equation()
# Out:
# x + 4*y/3 + 5/3

# %%
#reflection through y axis
z.transform(Matrix([[-1,0,0],[0,1,0],[0,0,1]]))
# Out:
# Point2D(-4, -2)

# %%
#reflection thr. x axis
z.transform(Matrix([[1,0,0],[0,1,0],[0,0,-1]]))
# Out:
# Point2D(4, -2)

# %%
#reflection thr. y=-x
z.transform(Matrix([[0,0,-1],[0,1,0],[-1,0,0]]))
# Out:
# Point2D(-1, -2)

# %%
#reflection thr. y=x
z.transform(Matrix([[0,0,1],[0,1,0],[1,0,0]]))
# Out:
# Point2D(1, -2)

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
ax=axes(projection='3d')
xlabel('x-axis')
ylabel('z-axis')
plot(70, -25, 15,marker='D',color='black')
plot(50, 72, -45,marker='*',color='g')
plot(58, -82, 65,marker='.',color='g')
plot(20, 72, -45,marker='*',color='r')

# %%
from sympy import*
s=Point(4,3)
s.rotate(pi/4)
# Out:
# Point2D(sqrt(2)/2, 7*sqrt(2)/2)

# %%
from math import*
angle=radians(48)
s.rotate(angle)
# Out:
# Point2D(1788351796013/4000000000000, 99599422419723/20000000000000)

# %%
from math import*
angle=radians(98)
s.rotate(angle)
# Out:
# Point2D(-352749661006497/100000000000000, 354355297208609/100000000000000)

# %%
l=Line(Point(0,0),Point(0,1))
l.rotate(pi/6)
# Out:
# Line2D(Point2D(0, 0), Point2D(-1/2, 866025403784439/1000000000000000))

# %%
l1=l.rotate(pi/6)
l1.equation()
# Out:
# -866025403784439*x/1000000000000000 - y/2

# %%
l=Line(Point(2,4),Point(7,3))
l.rotate(pi/6)
# Out:
# Line2D(Point2D(-133974596215561/500000000000000, 17856406460551/4000000000000), Point2D(456217782649107/100000000000000, 152451905283833/25000000000000))

# %%
l1=l.rotate(pi/6)
l1.equation()
# Out:
# -163397459621557*x/100000000000000 + 301882938682637*y/62500000000000 - 1099999999999998674929285045877/50000000000000000000000000000

# %%
l=Ray(Point(5,1),Point(0,8))
l.rotate(2*pi/3)
# Out:
# Ray2D(Point2D(-84150635094611/25000000000000, 383012701892219/100000000000000), Point2D(-692820323027551/100000000000000, -4))

# %%
l1=Segment(Point(1,2),Point(3,4))
l1.rotate(pi)
# Out:
# Segment2D(Point2D(-1, -2), Point2D(-3, -4))

# %%
A=Point(0,0)
B=Point(6,0)
C=Point(4,4)
T=Triangle(A,B,C)
T.area
# Out:
# 12

# %%
T.perimeter
# Out:
# 2*sqrt(5) + 4*sqrt(2) + 6

# %%
s=Segment(Point(4,-1),Point(3,0))
s.rotate(pi)
# Out:
# Segment2D(Point2D(-4, 1), Point2D(-3, 183697019872103/500000000000000000000000000000))

# %%
x,y=symbols('x,y')
s=Segment(Point(5,3),Point(1,4))
s.reflect(Line(y-x-1))
# Out:
# Segment2D(Point2D(2, 6), Point2D(3, 2))

# %%
x1, y1 = 0, 0
x2, y2 = 10, 10
x = (x1 + x2) / 2
y = (y1 + y2) / 2
print(x,y)
# Out:
# 5.0 5.0

# %%
import matplotlib.pyplot as plt
import numpy as np
height = [168, 190, 170, 178, 195]
city = ['Pune', 'Mumbai', 'Nasik', 'Nagpur', 'Thane']
plt.barh(city,height,color='r')
plt.xlabel('height')
plt.ylabel('city')
plt.title('city Vs height')
plt.plot()
# Out:
# []

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d
from pylab import*

# %%
def f(x,y):
    return np.sin(x**2+y**2)
x=np.linspace(0,10)
y=np.linspace(0,10)
X,Y=np.meshgrid(x,y)
z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,z,100)
plt.show()

# %%
from sympy import*
A=Point(0,0)
B=Point(2,0)
C=Point(2,3)
D=Point(1,6)
P=Polygon(A,B,C,D)
P.rotate(pi)
# Out:
# Polygon(Point2D(0, 0), Point2D(-2, 0), Point2D(-2, -3), Point2D(-1, -6))

# %%
p=Polygon((1,2),1,n=6)
p.area
# Out:
# 3*sqrt(3)/2

# %%
p.perimeter
# Out:
# 6

# %%
a=Point(6,2)
b=Point(10,4)
c=Point(8,7)
d=Point(4,8)
e=Point(2,4)
p=Polygon(a,b,c,d,e,color='red')
plt.show()

# %%
p=Polygon((0,0),8,n=5)
p.area
# Out:
# (800 - 160*sqrt(5))/(4*sqrt(5 - 2*sqrt(5)))

# %%
p.perimeter
# Out:
# 8*sqrt(-sqrt(5 - sqrt(5))*sqrt(sqrt(5) + 5) + 10) + 12*sqrt(10 - 2*sqrt(5))

# %%
a=Point(6,2)
b=Point(10,4)
c=Point(8,7)
t=Triangle(a,b,c)
t.angles[a]
# Out:
# acos(9*sqrt(145)/145)

# %%
t.angles[b]
# Out:
# acos(sqrt(65)/65)

# %%
t.angles[c]
# Out:
# acos(11*sqrt(377)/377)

# %%
x=np.arange(0,2*(np.pi),0.1)
y=np.cos(x)
plt.plot(x,y,color='magenta')
plt.show()

# %%
x=np.arange(0,5)
figure=plt.subplot()
y=np.sin(x)
w=np.exp(x)
z=x**3
plt.plot(x,y)
plt.plot(x,w)
plt.plot(x,z)
plt.show()

# %%
#Write a python program to Plot 2DX-axis and Y-axis black color and in the same diagram plot green triangle with vertices [5, 4], [7, 4], [6, 6].

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits import mplot3d
#x,y=np.linspace(0,0)
a=Point(5,4)
b=Point(7,4)
c=Point(6,6)
t=Triangle(a,b,c)
plt.plot(t,color='g')
#plt.plot(x,y,color='black')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[74], line 9
#       7 c=Point(6,6)
#       8 t=Triangle(a,b,c)
# ----> 9 plt.plot(t,color='g')
#      10 #plt.plot(x,y,color='black')
#      11 plt.show()
#
# File /lib/python3.11/site-packages/matplotlib/pyplot.py:2769, in plot(scalex, scaley, data, *args, **kwargs)
#    2767 @_copy_docstring_and_deprecators(Axes.plot)
#    2768 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2769     return gca().plot(
#    2770         *args, scalex=scalex, scaley=scaley,
#    2771         **({"data": data} if data is not None else {}), **kwargs)
#
# File /lib/python3.11/site-packages/matplotlib/axes/_axes.py:1634, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
#    1632 lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1633 for line in lines:
# -> 1634     self.add_line(line)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
ub=22
lb=-22
subinterval=80
x=np.linspace(lb,ub,subinterval+1)
print(x)
# Out:
# [-22.   -21.45 -20.9  -20.35 -19.8  -19.25 -18.7  -18.15 -17.6  -17.05
#  -16.5  -15.95 -15.4  -14.85 -14.3  -13.75 -13.2  -12.65 -12.1  -11.55
#  -11.   -10.45  -9.9   -9.35  -8.8   -8.25  -7.7   -7.15  -6.6   -6.05
#   -5.5   -4.95  -4.4   -3.85  -3.3   -2.75  -2.2   -1.65  -1.1   -0.55
#    0.     0.55   1.1    1.65   2.2    2.75   3.3    3.85   4.4    4.95
#    5.5    6.05   6.6    7.15   7.7    8.25   8.8    9.35   9.9   10.45
#   11.    11.55  12.1   12.65  13.2   13.75  14.3   14.85  15.4   15.95
#   16.5   17.05  17.6   18.15  18.7   19.25  19.8   20.35  20.9   21.45
#   22.  ]

# %%
import pulp as p
Lp_prob=p.LpProblem('Problem',p.LpMinimize)
x=p.LpVariable("x",lowBound=0)
y=p.LpVariable("y",lowBound=0)
Lp_prob+=x+y
Lp_prob+=x>=6
Lp_prob+=y>=6
Lp_prob+=x+y<=11
print(Lp_prob)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 import pulp as p
#       2 Lp_prob=p.Lpproblem('Problem',p.Lpminimize)
#       3 x=p.Lpvariable("x",lowbound=0)
#
# ModuleNotFoundError: No module named 'pulp'

# %%
import pulp as p
Lp_prob=p.LpProblem=('Problem',p.Lpminimize)
x=p.LpVariable("x",lowBound=0)
y=p.LpVariable=("y",lowBound=0)
Lp_prob=3.5*x+2*y
print(Lp_prob)
# Out:
#   Cell In[79], line 4
#     y=p.LpVariable=("y",lowBound=0)
#                         ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import pulp as p
Lp_prob=p.LpProblem('Problem',p.LpMaximize)
x=p.LpVariable("x",lowBound=0)
y=p.LpVarible("y",lowBound=0)
Lp_prob=
print(Lp_prob)

# %%
status=Lp_prob.solve()
print(p.LpStatus[status])
print(p.value(x),p.value(y),p.value(Lp_prob.objective))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 status=Lp_prob.solve()
#       2 print(p.LpStatus[status])
#       3 print(p.value(x),p.value(y),p.value(Lp_prob.objective))
#
# NameError: name 'Lp_prob' is not defined

# %%
status=Lp_prob.solve()
print(p.LpStatus[status])
print(p.value(x),p.value(y),p.value(Lp_prob.objective))
