# %%
#slip 1
#Q.1 Attempt any TWO of the following

# %%
#(a) Write a Python program to plot 2D graph of the functions f(x) = x**2 and g(x) = x**3 in [−1, 1]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(-1,1)
f=x**2
g=x**3
plt.plot(x,f,g)
plt.show()

# %%
#(b) Write a Python program to plot 3D graph of the function f(x) = e^−x^2in [−5, 5] with green dashed points line with upward pointing triangle.

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *

# %%
import matplotlib.pyplot as plt
def f(x,y):
    return np.exp((-x)**2)
x=np.linspace(-5,5)
y=np.linspace(-5,5)
X,Y=np.meshgrid(x,y)
z=f(X,Y)
ax=axes(projection='3d')
ax.plot_surface(X,Y,Z)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Using python, represent the following information using a bar graph (in green color )
#Item clothing Food rent Petrol Misc.
#expenditure in Rs 600 4000 2000 1500 700

# %%
import matplotlib.pyplot as plt
Item=['clothing','food','rent','petrol','misc']
Expendicture_in_Rs=[600,4000,2000,1500,700]
plt.bar(Item,Expendicture_in_Rs,color='green')
plt.show()

# %%
#slip 2
#Write a Python program to plot 2D graph of the functions f(x) = log10(x) in the interval [0, 10].

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,10)
y=np.log10(x)
plt.plot(x,y)
plt.show()

# %%
#Using python, generate 3D surface Plot for the function f(x) = sin(x**2+y**2) in the interval [0, 10]

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*

# %%
def f(x,y) :
    return sin(x**2+y**2)
x=np.linspace(0,10)
y=np.linspace(0,10)
ax=axes(projection='3d')
plt.plot(x,y)
legend()
show()

# %%
# Using python, draw a bar graph in GREEN colour to represent the data below:
#Subject Maths Science English Marathi Hindi
#Percentage of passing 68 90 70 85 9

# %%
import matplotlib.pyplot as plt
Subject=['maths','science','english','marathi','hindi']
Percentage_of_passing=[68,90,70,85,9]
plt.bar(Subject,Percentage_of_passing,color='g')
plt.show()

# %%
# Using Python plot the graph of function f(x) = cos(x) on the interval [0, 2π].

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(0,2*(np.pi))
y=cos(x)
plt.plot(x,y)
plt.show()

# %%
# Following is the information of students participating in various games in a school. Represent it by a Bar graph with bar width of 0.7 inches.
#Game Cricket Football Hockey Chess Tennis
#Number of students 65 30 54 10 20

# %%
import matplotlib.pyplot as plt
Game=['cricket','Football','Hockey','Chess','Tennis']
Number_of_Students=[65,30,54,10,20]
plt.xlabel('Game',color='b')
plt.ylabel('Number_of_Students',color='b')
plt.title('Game Vs Number_of_Students')
plt.pie(Game,Number_of_Students)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[49], line 7
#       5 plt.ylabel('Number_of_Students',color='b')
#       6 plt.title('Game Vs Number_of_Students')
# ----> 7 plt.pie('Game','Number_of_Students')
#       8 plt.show()
#
# File /lib/python3.11/site-packages/matplotlib/pyplot.py:2756, in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    2749 @_copy_docstring_and_deprecators(Axes.pie)
#    2750 def pie(
#    2751         x, explode=None, labels=None, colors=None, autopct=None,
#    (...)
#    2754         textprops=None, center=(0, 0), frame=False,
#    2755         rotatelabels=False, *, normalize=True, data=None):
# -> 2756     return gca().pie(
#    2757         x, explode=explode, labels=labels, colors=colors,
# ...

# %%
#Write a Python program to generate 3D plot of the functions z = sin x + cos y in −10 < x, y < 10.

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
def f(x,y) :
    return np.sin(x)+np.cos(y)
x=np.linspace(-10,10)
y=np.linspace(-10,10)
X,Y=np.meshgrid(x,y)
z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,z,40)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Using Python plot the surface plot of parabola z = x**2 + y**2 in −6 < x, y < 6

# %%
from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
from pylab import*
def f(x,y) :
    return x**2+y**2
x=np.linspace(-6,6,30)
y=np.linspace(-6,6,30)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Using Python plot the surface plot of function z = cos(x**2+y**2-0.5) in the interval from −1 < x, y < 1

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
def f(x,y):
    return np.cos(x**2+y**2-0.5)
x=np.linspace(-1,1)
y=np.linspace(-1,1)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#) Generate 3D surface Plot for the function f(x) = sin(x**2+y**2) in the interval [0, 10]

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import *
def f(x,y):
    return np.sin(np.sqrt(x**2+y**2))
x=np.linspace(0,10)
y=np.linspace(0,10)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.plot_surface(X,Y,Z)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
# Write a Python program to generate 3D plot of the functions z = sin x + cos y in the interval −10 < x, y < 10

# %%
from mpl_toolkits import mplot3d
import numpy as np
from pylab import*
def f(x,y):
    return np.sin(x)+np.cos(y)
x=np.linspace(-10,10)
y=np.linspace(-10,10)
X,Y=np.meshgrid(x,y)
Z=f(X,Y)
ax=axes(projection='3d')
ax.contour3D(X,Y,Z,50)
legend()
show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
#Write a Python program to plot 2D graph of the function f(x) = x**4 in [0, 5] with red dashed line with circle markers.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.linspace(0,5)
y=x**4
plt.plot(x,y,color='r',linestyle='dashed',marker='o')
plt.show()

# %%
#Write the Python program to plot the graph of the function, using def()
#f(x) = x**2 + 4   if −10 ≤ x < 5
#       3x + 9      if 5 ≤ x < 10

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt
import numpy as np
from pylab import*
def f(x):
    return x**2+4 or 3*x+9
x=np.linspace((-10,5),(5,10))
plt.plot(x)
show()

# %%
#Write a Python program to plot graph of the function f(x) = log(3x**2), in [1, 10] with black dashed points

# %%
import matplotlib.pyplot as plt
import numpy as np
x=np.linspace(1,10,10)
y=np.log(3*(x**2))
plt.plot(x,y,color='black',linestyle='--')
plt.show()
